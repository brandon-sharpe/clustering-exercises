# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from env import user, host, password
import os

# %% [markdown]
# # Zillow Clustering

# %%
def get_connection(db, username=user, host=host, password=password):
    '''
    Creates a connection URL
    '''
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

# %% [markdown]
# ### 1. Acquire data from mySQL using the python module to connect and query. You will want to end with a single dataframe. Make sure to include: the logerror, all fields related to the properties that are available. You will end up using all the tables in the database.
#
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.
# - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
# - Only include properties that include a latitude and longitude value.

# %%
def new_zillow_data():
    '''
    Returns zillow into a dataframe
    '''
    sql_query = '''  SELECT *
    FROM properties_2017
    LEFT OUTER JOIN airconditioningtype 
    USING (airconditioningtypeid)
    LEFT OUTER JOIN architecturalstyletype
    USING (architecturalstyletypeid)
    LEFT OUTER JOIN buildingclasstype 
    USING (buildingclasstypeid)
    LEFT OUTER JOIN heatingorsystemtype
    USING (heatingorsystemtypeid)
    LEFT OUTER JOIN predictions_2017
    USING (id)
    INNER JOIN (
    SELECT id, MAX(transactiondate) as last_trans_date 
    FROM predictions_2017
    GROUP BY id
    ) predictions ON predictions.id = properties_2017.id AND predictions_2017.transactiondate = predictions.last_trans_date
    LEFT OUTER JOIN propertylandusetype
    USING(propertylandusetypeid)
    LEFT OUTER JOIN storytype
    ON storytype.storytypeid = properties_2017.storytypeid
    LEFT OUTER JOIN typeconstructiontype
    ON typeconstructiontype.typeconstructiontypeid = properties_2017.typeconstructiontypeid
    JOIN unique_properties
    ON unique_properties.parcelid = properties_2017.parcelid
    WHERE latitude IS NOT NULL and longitude IS NOT NULL; '''
    df = pd.read_sql(sql_query, get_connection('zillow'))
    return df 

def get_zillow_data():
    '''get connection, returns zillow into a dataframe and creates a csv for us'''
    if os.path.isfile('zillow.csv'):
        df = pd.read_csv('zillow.csv', index_col=0)
    else:
        df = new_zillow_data()
        df.to_csv('zillow.csv')
    return df

def nulls_by_col(df):
    '''Returns a dataframe that shows the amount of null values in each column'''
    num_missing = df.isnull().sum()
    rows = df.shape[0]
    prcnt_miss = num_missing / rows * 100
    cols_missing = pd.DataFrame({'num_rows_missing': num_missing, 'percent_rows_missing': prcnt_miss})
    return cols_missing

def nulls_by_row(df):
    '''Returns a dataframe that shows the amount of null values in each row'''
    num_missing = df.isnull().sum(axis=1)
    prcnt_miss = num_missing / df.shape[1] * 100
    rows_missing = pd.DataFrame({'num_cols_missing': num_missing, 'percent_cols_missing': prcnt_miss})\
    .reset_index()\
    .groupby(['num_cols_missing', 'percent_cols_missing']).count()\
    .rename(index=str, columns={'customer_id': 'num_rows'}).reset_index()
    return rows_missing

# %%
zillow_df = get_zillow_data()
zillow_df.shape
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (61,62,71,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# (77614, 74)

# %%
zillow_df.parcelid.unique
# Out:
# <bound method Series.unique of 0        10754147
# 1        10759547
# 2        10843547
# 3        10859147
# 4        10879947
#            ...
# 77609    11212539
# 77610    11212639
# 77611    11212962
# 77612    11213162
# 77613    11213262
# Name: parcelid, Length: 77614, dtype: int64>

# %% [markdown]
# ### 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)

# %%
zillow_df.shape
# Out:
# (77614, 74)

# %%
zillow_df.describe().T
# Out:
#                             count          mean           std           min  \
# propertylandusetypeid     77614.0  2.599353e+02  1.696516e+01  3.100000e+01
# id                        77614.0  3.880650e+04  2.240538e+04  0.000000e+00
# heatingorsystemtypeid     48475.0  4.043012e+00  3.231120e+00  1.000000e+00
# buildingclasstypeid         383.0  3.775457e+00  4.595960e-01  1.000000e+00
# architecturalstyletypeid    151.0  7.430464e+00  2.629347e+00  2.000000e+00
# ...                           ...           ...           ...           ...
# logerror                  77614.0  1.675218e-02  1.708879e-01 -4.655420e+00
# id.1                      77614.0  3.880650e+04  2.240538e+04  0.000000e+00
# storytypeid.1                45.0  7.000000e+00  0.000000e+00  7.000000e+00
# typeconstructiontypeid.1    166.0  5.987952e+00  1.552301e-01  4.000000e+00
# parcelid.2                77614.0  1.337943e+07  8.351448e+06  1.071174e+07
#
#                                    25%           50%           75%  \
# propertylandusetypeid     2.610000e+02  2.610000e+02  2.610000e+02
# id                        1.940325e+04  3.880650e+04  5.820975e+04
# heatingorsystemtypeid     2.000000e+00  2.000000e+00  7.000000e+00
# buildingclasstypeid       4.000000e+00  4.000000e+00  4.000000e+00
# architecturalstyletypeid  7.000000e+00  7.000000e+00  7.000000e+00
# ...                                ...           ...           ...
# logerror                 -2.432860e-02  6.669808e-03  3.929424e-02
# id.1                      1.940325e+04  3.880650e+04  5.820975e+04
# storytypeid.1             7.000000e+00  7.000000e+00  7.000000e+00
# typeconstructiontypeid.1  6.000000e+00  6.000000e+00  6.000000e+00
# parcelid.2                1.158572e+07  1.253225e+07  1.411509e+07
#
#                                    max
# propertylandusetypeid     2.750000e+02
# id                        7.761300e+04
# heatingorsystemtypeid     2.400000e+01
# buildingclasstypeid       5.000000e+00
# architecturalstyletypeid  2.100000e+01
# ...                                ...
# logerror                  5.262999e+00
# id.1                      7.761300e+04
# storytypeid.1             7.000000e+00
# typeconstructiontypeid.1  6.000000e+00
# parcelid.2                1.696019e+08
#
# [62 rows x 8 columns]

# %%
zillow_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77614 entries, 0 to 77613
# Data columns (total 74 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   propertylandusetypeid         77614 non-null  float64
#  1   id                            77614 non-null  int64
#  2   heatingorsystemtypeid         48475 non-null  float64
#  3   buildingclasstypeid           383 non-null    float64
#  4   architecturalstyletypeid      151 non-null    float64
#  5   airconditioningtypeid         21457 non-null  float64
#  6   parcelid                      77614 non-null  int64
#  7   basementsqft                  45 non-null     float64
#  8   bathroomcnt                   77614 non-null  float64
#  9   bedroomcnt                    77614 non-null  float64
#  10  buildingqualitytypeid         50322 non-null  float64
#  11  calculatedbathnbr             74391 non-null  float64
#  12  decktypeid                    513 non-null    float64
#  13  finishedfloor1squarefeet      5973 non-null   float64
#  14  calculatedfinishedsquarefeet  76502 non-null  float64
#  15  finishedsquarefeet12          70964 non-null  float64
#  16  finishedsquarefeet13          235 non-null    float64
#  17  finishedsquarefeet15          4758 non-null   float64
#  18  finishedsquarefeet50          5973 non-null   float64
#  19  finishedsquarefeet6           545 non-null    float64
#  20  fips                          77614 non-null  float64
#  21  fireplacecnt                  8412 non-null   float64
#  22  fullbathcnt                   74391 non-null  float64
#  23  garagecarcnt                  23300 non-null  float64
#  24  garagetotalsqft               23300 non-null  float64
#  25  hashottuborspa                1258 non-null   float64
#  26  latitude                      77614 non-null  float64
#  27  longitude                     77614 non-null  float64
#  28  lotsizesquarefeet             70535 non-null  float64
#  29  poolcnt                       14261 non-null  float64
#  30  poolsizesum                   777 non-null    float64
#  31  pooltypeid10                  424 non-null    float64
#  32  pooltypeid2                   834 non-null    float64
#  33  pooltypeid7                   13409 non-null  float64
#  34  propertycountylandusecode     77613 non-null  object
#  35  propertyzoningdesc            51362 non-null  object
#  36  rawcensustractandblock        77614 non-null  float64
#  37  regionidcity                  76088 non-null  float64
#  38  regionidcounty                77614 non-null  float64
#  39  regionidneighborhood          30512 non-null  float64
#  40  regionidzip                   77339 non-null  float64
#  41  roomcnt                       77613 non-null  float64
#  42  storytypeid                   45 non-null     float64
#  43  threequarterbathnbr           8204 non-null   float64
#  44  typeconstructiontypeid        166 non-null    float64
#  45  unitcnt                       51290 non-null  float64
#  46  yardbuildingsqft17            2423 non-null   float64
#  47  yardbuildingsqft26            66 non-null     float64
#  48  yearbuilt                     76444 non-null  float64
#  49  numberofstories               18119 non-null  float64
#  50  fireplaceflag                 125 non-null    float64
#  51  structuretaxvaluedollarcnt    76349 non-null  float64
#  52  taxvaluedollarcnt             76689 non-null  float64
#  53  assessmentyear                77614 non-null  float64
#  54  landtaxvaluedollarcnt         76003 non-null  float64
#  55  taxamount                     77103 non-null  float64
#  56  taxdelinquencyflag            1505 non-null   object
#  57  taxdelinquencyyear            1505 non-null   float64
#  58  censustractandblock           75519 non-null  float64
#  59  airconditioningdesc           21457 non-null  object
#  60  architecturalstyledesc        151 non-null    object
#  61  buildingclassdesc             383 non-null    object
#  62  heatingorsystemdesc           48475 non-null  object
#  63  parcelid.1                    77614 non-null  int64
#  64  logerror                      77614 non-null  float64
#  65  transactiondate               77614 non-null  object
#  66  id.1                          77614 non-null  int64
#  67  last_trans_date               77614 non-null  object
#  68  propertylandusedesc           77614 non-null  object
#  69  storytypeid.1                 45 non-null     float64
#  70  storydesc                     45 non-null     object
#  71  typeconstructiontypeid.1      166 non-null    float64
#  72  typeconstructiondesc          166 non-null    object
#  73  parcelid.2                    77614 non-null  int64
# dtypes: float64(57), int64(5), object(12)
# memory usage: 44.4+ MB

# %% [markdown]
# ### 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
def missing_values_table(df):
    '''
    this function takes a dataframe as input and will output metrics for missing values, and the percent of that column that has missing values
    '''
        # Total missing values
    mis_val = df.isnull().sum()
        # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
        # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
    mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
           "There are " + str(mis_val_table_ren_columns.shape[0]) +
           "columns that have missing values.")
        # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
missing_values_table(zillow_df)
# Out:
# Your selected dataframe has 74 columns.
# There are 56columns that have missing values.
#                               Missing Values  % of Total Values
# basementsqft                           77569               99.9
# storydesc                              77569               99.9
# storytypeid                            77569               99.9
# storytypeid.1                          77569               99.9
# yardbuildingsqft26                     77548               99.9
# fireplaceflag                          77489               99.8
# architecturalstyletypeid               77463               99.8
# architecturalstyledesc                 77463               99.8
# typeconstructiondesc                   77448               99.8
# typeconstructiontypeid                 77448               99.8
# typeconstructiontypeid.1               77448               99.8
# finishedsquarefeet13                   77379               99.7
# buildingclasstypeid                    77231               99.5
# buildingclassdesc                      77231               99.5
# pooltypeid10                           77190               99.5
# decktypeid                             77101               99.3
# finishedsquarefeet6                    77069               99.3
# poolsizesum                            76837               99.0
# pooltypeid2                            76780               98.9
# hashottuborspa                         76356               98.4
# taxdelinquencyflag                     76109               98.1
# taxdelinquencyyear                     76109               98.1
# yardbuildingsqft17                     75191               96.9
# finishedsquarefeet15                   72856               93.9
# finishedsquarefeet50                   71641               92.3
# finishedfloor1squarefeet               71641               92.3
# threequarterbathnbr                    69410               89.4
# fireplacecnt                           69202               89.2
# pooltypeid7                            64205               82.7
# poolcnt                                63353               81.6
# numberofstories                        59495               76.7
# airconditioningdesc                    56157               72.4
# airconditioningtypeid                  56157               72.4
# garagecarcnt                           54314               70.0
# garagetotalsqft                        54314               70.0
# regionidneighborhood                   47102               60.7
# heatingorsystemdesc                    29139               37.5
# heatingorsystemtypeid                  29139               37.5
# buildingqualitytypeid                  27292               35.2
# unitcnt                                26324               33.9
# propertyzoningdesc                     26252               33.8
# lotsizesquarefeet                       7079                9.1
# finishedsquarefeet12                    6650                8.6
# calculatedbathnbr                       3223                4.2
# fullbathcnt                             3223                4.2
# censustractandblock                     2095                2.7
# landtaxvaluedollarcnt                   1611                2.1
# regionidcity                            1526                2.0
# structuretaxvaluedollarcnt              1265                1.6
# yearbuilt                               1170                1.5
# calculatedfinishedsquarefeet            1112                1.4
# taxvaluedollarcnt                        925                1.2
# taxamount                                511                0.7
# regionidzip                              275                0.4
# propertycountylandusecode                  1                0.0
# roomcnt                                    1                0.0

# %% [markdown]
# ### 4. Write a function that takes in a dataframe and returns a dataframe with 3 columns: the number of columns missing, percent of columns missing, and number of rows with n columns missing. Run the function and document takeaways from this on how you want to handle missing values.

# %%
zillow = pd.DataFrame(zillow_df.isnull().sum(axis =1), columns = ['num_cols_missing']).reset_index().groupby('num_cols_missing').count().reset_index().rename(columns = {'index': 'num_rows' })
zillow
# Out:
#     num_cols_missing  num_rows
# 0                 25        12
# 1                 26        21
# 2                 27        42
# 3                 28        43
# 4                 29       160
# 5                 30       351
# 6                 31      4281
# 7                 32      2851
# 8                 33      8974
# 9                 34     11544
# 10                35     15184
# 11                36     15433
# 12                37      5681
# 13                38      6030
# 14                39      2861
# 15                40      1383
# 16                41       296
# 17                42       297
# 18                43        71
# 19                44        63
# 20                45       121
# 21                46       123
# 22                47       449
# 23                48       998
# 24                49       212
# 25                50        92
# 26                51        38
# 27                52         3

# %%
zillow['%_cols_missing'] = zillow.num_cols_missing/zillow.shape[1]

# %%
def cols_missing(df):
    df = pd.DataFrame(df.isnull().sum(axis =1), columns = ['num_cols_missing'])\
    .reset_index().groupby('num_cols_missing').count()\
    .reset_index().rename(columns = {'index': 'num_rows' })
    df['pct_cols_missing'] = df.num_cols_missing/df.shape[1] 
    return df

# %%
cols_missing(zillow_df)
# Out:
#     num_cols_missing  num_rows  pct_cols_missing
# 0                 25        12              12.5
# 1                 26        21              13.0
# 2                 27        42              13.5
# 3                 28        43              14.0
# 4                 29       160              14.5
# 5                 30       351              15.0
# 6                 31      4281              15.5
# 7                 32      2851              16.0
# 8                 33      8974              16.5
# 9                 34     11544              17.0
# 10                35     15184              17.5
# 11                36     15433              18.0
# 12                37      5681              18.5
# 13                38      6030              19.0
# 14                39      2861              19.5
# 15                40      1383              20.0
# 16                41       296              20.5
# 17                42       297              21.0
# 18                43        71              21.5
# 19                44        63              22.0
# 20                45       121              22.5
# 21                46       123              23.0
# 22                47       449              23.5
# 23                48       998              24.0
# 24                49       212              24.5
# 25                50        92              25.0
# 26                51        38              25.5
# 27                52         3              26.0

# %% [markdown]
# Currently, I have no clue on how I want to approach missing values. Perhaps I could Impute them, or I could drop them entirely. I'd like to avoid dropping because I only have 77000 rows and I don't want to prune down my dataset too much. It will already be reduced from dropping outliers and also during the train test split.

# %% [markdown]
# ## Acquire

# %% [markdown]
# ### 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer. But for this exercise, do not purely filter by unitcnt as we did previously. Add some new logic that will reduce the number of properties that are falsely removed. You might want to use # bedrooms, square feet, unit type or the like to then identify those with unitcnt not defined.

# %%
zillow_df.shape
# Out:
# (77614, 74)

# %%
single_use_codes = [261, 262, 263, 266, 268, 273, 276, 279]
zillow_df = zillow_df[zillow_df['propertylandusetypeid'].isin(single_use_codes)]

zillow_df
# Out:
#        propertylandusetypeid     id  heatingorsystemtypeid  \
# 1                      261.0      1                    NaN
# 14                     266.0     14                    NaN
# 15                     261.0     15                    NaN
# 16                     261.0     16                    NaN
# 17                     261.0     17                    NaN
# ...                      ...    ...                    ...
# 77609                  261.0  77609                    2.0
# 77610                  261.0  77610                    2.0
# 77611                  261.0  77611                    2.0
# 77612                  266.0  77612                    2.0
# 77613                  261.0  77613                    2.0
#
#        buildingclasstypeid  architecturalstyletypeid  airconditioningtypeid  \
# 1                      NaN                       NaN                    NaN
# 14                     NaN                       NaN                    NaN
# 15                     NaN                       NaN                    NaN
# 16                     NaN                       NaN                    NaN
# 17                     NaN                       NaN                    NaN
# ...                    ...                       ...                    ...
# 77609                  NaN                       NaN                    1.0
# 77610                  NaN                       NaN                    1.0
# 77611                  NaN                       NaN                    1.0
# 77612                  NaN                       NaN                    1.0
# 77613                  NaN                       NaN                    1.0
#
#        parcelid  basementsqft  bathroomcnt  bedroomcnt  ...  logerror  \
# 1      10759547           NaN          0.0         0.0  ...  0.055619
# 14     11142747           NaN          0.0         0.0  ... -0.008935
# 15     11193347           NaN          0.0         0.0  ...  0.008669
# 16     11215747           NaN          0.0         0.0  ... -0.021896
# 17     11229347           NaN          0.0         0.0  ... -0.017167
# ...         ...           ...          ...         ...  ...       ...
# 77609  11212539           NaN          3.0         4.0  ...  0.020615
# 77610  11212639           NaN          3.0         4.0  ...  0.013209
# 77611  11212962           NaN          2.0         3.0  ...  0.037129
# 77612  11213162           NaN          3.0         3.0  ...  0.007204
# 77613  11213262           NaN          3.0         4.0  ... -0.197755
#
#        transactiondate   id.1  last_trans_date        propertylandusedesc  \
# 1           2017-01-01      1       2017-01-01  Single Family Residential
# 14          2017-01-02     14       2017-01-02                Condominium
# 15          2017-01-02     15       2017-01-02  Single Family Residential
# 16          2017-01-02     16       2017-01-02  Single Family Residential
# 17          2017-01-02     17       2017-01-02  Single Family Residential
# ...                ...    ...              ...                        ...
# 77609       2017-09-20  77609       2017-09-20  Single Family Residential
# 77610       2017-09-21  77610       2017-09-21  Single Family Residential
# 77611       2017-09-21  77611       2017-09-21  Single Family Residential
# 77612       2017-09-25  77612       2017-09-25                Condominium
# 77613       2018-05-25  77613       2018-05-25  Single Family Residential
#
#        storytypeid.1  storydesc  typeconstructiontypeid.1  \
# 1                NaN        NaN                       NaN
# 14               NaN        NaN                       NaN
# 15               NaN        NaN                       NaN
# 16               NaN        NaN                       NaN
# 17               NaN        NaN                       NaN
# ...              ...        ...                       ...
# 77609            NaN        NaN                       NaN
# 77610            NaN        NaN                       NaN
# 77611            NaN        NaN                       NaN
# 77612            NaN        NaN                       NaN
# 77613            NaN        NaN                       NaN
#
#        typeconstructiondesc  parcelid.2
# 1                       NaN    10759547
# 14                      NaN    11142747
# 15                      NaN    11193347
# 16                      NaN    11215747
# 17                      NaN    11229347
# ...                     ...         ...
# 77609                   NaN    11212539
# 77610                   NaN    11212639
# 77611                   NaN    11212962
# 77612                   NaN    11213162
# 77613                   NaN    11213262
#
# [70252 rows x 74 columns]

# %% [markdown]
# ### 2. Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
#
# - The input:
#     - A dataframe
#     - A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#     - A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#     - The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#     - Look up the dropna documentation.
#     - You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
#     - Make use of inplace, i.e. inplace=True/False.

# %%
zillow_df.shape
# Out:
# (70252, 74)

# %%
prop_req_col = .75
prop_req_row = .5

# %%
threshold = int(prop_req_col * len(zillow_df.index))
threshold = int(prop_req_row * len(zillow_df.columns)) 
zillow_df.dropna(axis = 0, thresh = threshold, inplace = True)

# %%
zillow_df.shape
# Out:
# (59380, 74)

# %%
def drop_nulls(df, prop_req_col = .5 , prop_req_row = .5, inplace = True):
    threshold = int(prop_req_col * len(df.index)) 
    df.dropna(axis = 1, thresh = threshold, inplace = True)
    threshold = int(prop_req_row * len(df.columns)) 
    df.dropna(axis = 0, thresh = threshold, inplace = True)
    return df

# %%
drop_nulls(zillow_df, prop_req_col = .75)
# Out:
#        propertylandusetypeid     id  heatingorsystemtypeid  parcelid  \
# 20                     261.0     20                    2.0  11324547
# 30                     266.0     30                    2.0  11524947
# 31                     261.0     31                    2.0  11544747
# 33                     261.0     33                    2.0  11585547
# 37                     266.0     37                    2.0  11617547
# ...                      ...    ...                    ...       ...
# 77609                  261.0  77609                    2.0  11212539
# 77610                  261.0  77610                    2.0  11212639
# 77611                  261.0  77611                    2.0  11212962
# 77612                  266.0  77612                    2.0  11213162
# 77613                  261.0  77613                    2.0  11213262
#
#        bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 20             2.0         4.0                2.0
# 30             2.0         2.0                2.0
# 31             4.0         3.0                4.0
# 33             2.0         3.0                2.0
# 37             3.0         2.0                3.0
# ...            ...         ...                ...
# 77609          3.0         4.0                3.0
# 77610          3.0         4.0                3.0
# 77611          2.0         3.0                2.0
# 77612          3.0         3.0                3.0
# 77613          3.0         4.0                3.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12    fips  ...  \
# 20                           3633.0                3633.0  6037.0  ...
# 30                           1090.0                1090.0  6037.0  ...
# 31                           1620.0                1620.0  6037.0  ...
# 33                           2077.0                2077.0  6037.0  ...
# 37                           2735.0                2735.0  6037.0  ...
# ...                             ...                   ...     ...  ...
# 77609                        1921.0                1921.0  6037.0  ...
# 77610                        1780.0                1780.0  6037.0  ...
# 77611                        1549.0                1549.0  6037.0  ...
# 77612                        1339.0                1339.0  6037.0  ...
# 77613                        2059.0                2059.0  6037.0  ...
#
#        taxamount  censustractandblock  heatingorsystemdesc  parcelid.1  \
# 20       6941.39                  NaN              Central    12325145
# 30       6165.36                  NaN              Central    12713253
# 31      10244.94                  NaN              Central    14338242
# 33       7924.68                  NaN              Central    12155445
# 37      34982.17                  NaN              Central    11682477
# ...          ...                  ...                  ...         ...
# 77609    2860.33         6.037911e+13              Central    11000655
# 77610    2394.26         6.037911e+13              Central    17239384
# 77611    3331.81         6.037911e+13              Central    12773139
# 77612    2510.53         6.037911e+13              Central    12826780
# 77613    2470.35         6.037911e+13              Central    13083743
#
#        logerror  transactiondate   id.1  last_trans_date  \
# 20     0.042463       2017-01-02     20       2017-01-02
# 30     0.021853       2017-01-02     30       2017-01-02
# 31    -0.019546       2017-01-02     31       2017-01-02
# 33    -0.040807       2017-01-02     33       2017-01-02
# 37     0.026208       2017-01-02     37       2017-01-02
# ...         ...              ...    ...              ...
# 77609  0.020615       2017-09-20  77609       2017-09-20
# 77610  0.013209       2017-09-21  77610       2017-09-21
# 77611  0.037129       2017-09-21  77611       2017-09-21
# 77612  0.007204       2017-09-25  77612       2017-09-25
# 77613 -0.197755       2018-05-25  77613       2018-05-25
#
#              propertylandusedesc  parcelid.2
# 20     Single Family Residential    11324547
# 30                   Condominium    11524947
# 31     Single Family Residential    11544747
# 33     Single Family Residential    11585547
# 37                   Condominium    11617547
# ...                          ...         ...
# 77609  Single Family Residential    11212539
# 77610  Single Family Residential    11212639
# 77611  Single Family Residential    11212962
# 77612                Condominium    11213162
# 77613  Single Family Residential    11213262
#
# [59380 rows x 35 columns]

# %%
def remove_outliers(df, k, col_list):
    ''' remove outliers from a list of columns in a dataframe 
        and return that dataframe
    '''
    
    for col in col_list:

        q1, q3 = df[f'{col}'].quantile([.25, .75])  # get quartiles
        
        iqr = q3 - q1   # calculate interquartile range
        
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound

        # return dataframe without outliers
        
        df = df[(df[f'{col}'] > lower_bound) & (df[f'{col}'] < upper_bound)]
        
    return df

# %%
remove_outliers(zillow_df, 1.5, ['bedroomcnt','bathroomcnt','calculatedfinishedsquarefeet'])
# Out:
#        propertylandusetypeid     id  heatingorsystemtypeid  parcelid  \
# 30                     266.0     30                    2.0  11524947
# 31                     261.0     31                    2.0  11544747
# 33                     261.0     33                    2.0  11585547
# 37                     266.0     37                    2.0  11617547
# 72                     266.0     72                    2.0  12096947
# ...                      ...    ...                    ...       ...
# 77609                  261.0  77609                    2.0  11212539
# 77610                  261.0  77610                    2.0  11212639
# 77611                  261.0  77611                    2.0  11212962
# 77612                  266.0  77612                    2.0  11213162
# 77613                  261.0  77613                    2.0  11213262
#
#        bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 30             2.0         2.0                2.0
# 31             4.0         3.0                4.0
# 33             2.0         3.0                2.0
# 37             3.0         2.0                3.0
# 72             3.0         2.0                3.0
# ...            ...         ...                ...
# 77609          3.0         4.0                3.0
# 77610          3.0         4.0                3.0
# 77611          2.0         3.0                2.0
# 77612          3.0         3.0                3.0
# 77613          3.0         4.0                3.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12    fips  ...  \
# 30                           1090.0                1090.0  6037.0  ...
# 31                           1620.0                1620.0  6037.0  ...
# 33                           2077.0                2077.0  6037.0  ...
# 37                           2735.0                2735.0  6037.0  ...
# 72                           2510.0                2510.0  6037.0  ...
# ...                             ...                   ...     ...  ...
# 77609                        1921.0                1921.0  6037.0  ...
# 77610                        1780.0                1780.0  6037.0  ...
# 77611                        1549.0                1549.0  6037.0  ...
# 77612                        1339.0                1339.0  6037.0  ...
# 77613                        2059.0                2059.0  6037.0  ...
#
#        taxamount  censustractandblock  heatingorsystemdesc  parcelid.1  \
# 30       6165.36                  NaN              Central    12713253
# 31      10244.94                  NaN              Central    14338242
# 33       7924.68                  NaN              Central    12155445
# 37      34982.17                  NaN              Central    11682477
# 72       9378.06                  NaN              Central    11023776
# ...          ...                  ...                  ...         ...
# 77609    2860.33         6.037911e+13              Central    11000655
# 77610    2394.26         6.037911e+13              Central    17239384
# 77611    3331.81         6.037911e+13              Central    12773139
# 77612    2510.53         6.037911e+13              Central    12826780
# 77613    2470.35         6.037911e+13              Central    13083743
#
#        logerror  transactiondate   id.1  last_trans_date  \
# 30     0.021853       2017-01-02     30       2017-01-02
# 31    -0.019546       2017-01-02     31       2017-01-02
# 33    -0.040807       2017-01-02     33       2017-01-02
# 37     0.026208       2017-01-02     37       2017-01-02
# 72     0.093134       2017-01-02     72       2017-01-02
# ...         ...              ...    ...              ...
# 77609  0.020615       2017-09-20  77609       2017-09-20
# 77610  0.013209       2017-09-21  77610       2017-09-21
# 77611  0.037129       2017-09-21  77611       2017-09-21
# 77612  0.007204       2017-09-25  77612       2017-09-25
# 77613 -0.197755       2018-05-25  77613       2018-05-25
#
#              propertylandusedesc  parcelid.2
# 30                   Condominium    11524947
# 31     Single Family Residential    11544747
# 33     Single Family Residential    11585547
# 37                   Condominium    11617547
# 72                   Condominium    12096947
# ...                          ...         ...
# 77609  Single Family Residential    11212539
# 77610  Single Family Residential    11212639
# 77611  Single Family Residential    11212962
# 77612                Condominium    11213162
# 77613  Single Family Residential    11213262
#
# [53610 rows x 35 columns]

# %%
zillow_df = zillow_df.drop(columns=['finishedsquarefeet12','lotsizesquarefeet','regionidcity','regionidzip','censustractandblock'])

# %%
zillow_df['latitude'] /= 1000000.
zillow_df['longitude'] /= 1000000.

# %%
zillow_df.dropna()
# Out:
#        propertylandusetypeid     id  heatingorsystemtypeid  parcelid  \
# 20                     261.0     20                    2.0  11324547
# 30                     266.0     30                    2.0  11524947
# 31                     261.0     31                    2.0  11544747
# 33                     261.0     33                    2.0  11585547
# 37                     266.0     37                    2.0  11617547
# ...                      ...    ...                    ...       ...
# 77609                  261.0  77609                    2.0  11212539
# 77610                  261.0  77610                    2.0  11212639
# 77611                  261.0  77611                    2.0  11212962
# 77612                  266.0  77612                    2.0  11213162
# 77613                  261.0  77613                    2.0  11213262
#
#        bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 20             2.0         4.0                2.0
# 30             2.0         2.0                2.0
# 31             4.0         3.0                4.0
# 33             2.0         3.0                2.0
# 37             3.0         2.0                3.0
# ...            ...         ...                ...
# 77609          3.0         4.0                3.0
# 77610          3.0         4.0                3.0
# 77611          2.0         3.0                2.0
# 77612          3.0         3.0                3.0
# 77613          3.0         4.0                3.0
#
#        calculatedfinishedsquarefeet    fips  fullbathcnt  ...  \
# 20                           3633.0  6037.0          2.0  ...
# 30                           1090.0  6037.0          2.0  ...
# 31                           1620.0  6037.0          4.0  ...
# 33                           2077.0  6037.0          2.0  ...
# 37                           2735.0  6037.0          3.0  ...
# ...                             ...     ...          ...  ...
# 77609                        1921.0  6037.0          3.0  ...
# 77610                        1780.0  6037.0          3.0  ...
# 77611                        1549.0  6037.0          2.0  ...
# 77612                        1339.0  6037.0          3.0  ...
# 77613                        2059.0  6037.0          3.0  ...
#
#        landtaxvaluedollarcnt  taxamount heatingorsystemdesc  parcelid.1  \
# 20                   74104.0    6941.39             Central    12325145
# 30                  124671.0    6165.36             Central    12713253
# 31                  508238.0   10244.94             Central    14338242
# 33                  436568.0    7924.68             Central    12155445
# 37                 2164522.0   34982.17             Central    11682477
# ...                      ...        ...                 ...         ...
# 77609                32453.0    2860.33             Central    11000655
# 77610                25179.0    2394.26             Central    17239384
# 77611                49747.0    3331.81             Central    12773139
# 77612                29700.0    2510.53             Central    12826780
# 77613                26057.0    2470.35             Central    13083743
#
#        logerror  transactiondate   id.1  last_trans_date  \
# 20     0.042463       2017-01-02     20       2017-01-02
# 30     0.021853       2017-01-02     30       2017-01-02
# 31    -0.019546       2017-01-02     31       2017-01-02
# 33    -0.040807       2017-01-02     33       2017-01-02
# 37     0.026208       2017-01-02     37       2017-01-02
# ...         ...              ...    ...              ...
# 77609  0.020615       2017-09-20  77609       2017-09-20
# 77610  0.013209       2017-09-21  77610       2017-09-21
# 77611  0.037129       2017-09-21  77611       2017-09-21
# 77612  0.007204       2017-09-25  77612       2017-09-25
# 77613 -0.197755       2018-05-25  77613       2018-05-25
#
#              propertylandusedesc  parcelid.2
# 20     Single Family Residential    11324547
# 30                   Condominium    11524947
# 31     Single Family Residential    11544747
# 33     Single Family Residential    11585547
# 37                   Condominium    11617547
# ...                          ...         ...
# 77609  Single Family Residential    11212539
# 77610  Single Family Residential    11212639
# 77611  Single Family Residential    11212962
# 77612                Condominium    11213162
# 77613  Single Family Residential    11213262
#
# [45017 rows x 30 columns]
